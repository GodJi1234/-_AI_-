# %% [markdown]
# <a href="https://colab.research.google.com/github/GodJi1234/Dacon_AI_1/blob/main/Dacon_%EA%B5%AD%EB%AF%BC%EB%8C%80%ED%95%99%EA%B5%90_1%ED%9A%8C_%EA%B2%BD%EC%A7%84%EB%8C%80%ED%9A%8C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %%
apply_train_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/apply_train.csv')

# %%
company_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/company.csv')

# %%
recruitment_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/recruitment.csv')

# %%
resume_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/resume.csv')

# %%
resume_certificate_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/resume_certificate.csv')

# %%
resume_language_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/resume_language.csv')

# %%
resume_language_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/resume_language.csv')

# %%
resume_education_df = pd.read_csv('/content/drive/MyDrive/6.Dacon/제1회_국민대학교_AI빅데이터_분석_경진대회/resume_education.csv')

# %%
# apply_train_df
# company_df
# recruitment_df
# resume_df
# resume_certificate_df
resume_education_df
# resume_language_df
# sample_submission_df
# Out:
#      resume_seq  hischool_type_seq hischool_special_type hischool_nation  \
# 0        U01419                 21                   일반고              사립
# 1        U03375                 21                   일반고              사립
# 2        U06523                 21                   일반고              사립
# 3        U06619                 21                   일반고              사립
# 4        U05015                 16                  특성화고              공립
# ...         ...                ...                   ...             ...
# 8477     U06326                 21                   일반고              사립
# 8478     U07284                  0                    기타              기타
# 8479     U04109                 21                   일반고              공립
# 8480     U01863                 21                   일반고              사립
# 8481     U05884                  0                    기타              기타
#
#      hischool_gender  hischool_location_seq  univ_type_seq1  univ_type_seq2  \
# ...
